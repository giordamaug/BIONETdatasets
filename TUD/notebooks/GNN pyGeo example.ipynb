# %% [markdown]
# <a href="https://colab.research.google.com/github/giordamaug/BIONETdatasets/blob/main/TUD/notebooks/GNN pyGeo example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/giordamaug/BIONETdatasets/main?filepath=TUD%2Fnotebooks%2FGNN+pyGeo+example.ipynb)
# <a href="https://kaggle.com/kernels/welcome?src=https://github.com/giordamaug/BIONETdatasets/blob/main/TUD/notebooks/GNN pyGeo example.ipynb" target="_parent"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" alt="Open In Kaggle"/></a>

# %% [markdown]
# # Install StellargGraph library (if required)

# %%
# !pip install torch-scatter
# !pip install torch-sparse
# !pip install torch-cluster
# !pip install torch-spline-conv
# !pip install torch-geometric
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Looking in links: https://pytorch-geometric.com/whl/torch-1.10.0.html
# Collecting torch-scatter==2.0.5
#   Downloading torch_scatter-2.0.5.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: torch-scatter
#   Building wheel for torch-scatter (setup.py) ... done
#   Created wheel for torch-scatter: filename=torch_scatter-2.0.5-cp39-cp39-macosx_10_13_x86_64.whl size=364028 sha256=b78c9da9623d9889ce4ac722bdc41863cd0a599e5ed867e892b43561bcc4e2ac
#   Stored in directory: /Users/maurizio/Library/Caches/pip/wheels/a1/3b/1a/b1a8b1b9e2ef93724eef0abaf9ce0160673331cb28e4de6672
# Successfully built torch-scatter
# Installing collected packages: torch-scatter
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Successfully installed torch-scatter-2.0.5
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Looking in links: https://pytorch-geometric.com/whl/torch-1.10.0.html
# Collecting torch-sparse==0.6.8
#   Downloading torch_sparse-0.6.8.tar.gz (34 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/site-packages (from torch-sparse==0.6.8) (1.7.2)
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in /usr/local/lib/python3.9/site-packages (from scipy->torch-sparse==0.6.8) (1.19.5)
# Building wheels for collected packages: torch-sparse
#   Building wheel for torch-sparse (setup.py) ... done
#   Created wheel for torch-sparse: filename=torch_sparse-0.6.8-cp39-cp39-macosx_10_13_x86_64.whl size=373940 sha256=79539b20a7235befe64471150fb56effb8acd0ffb4ecc76372b24dd93401c900
#   Stored in directory: /Users/maurizio/Library/Caches/pip/wheels/a1/d2/cb/9fec5a1f073b8d2d2ecb9778cf7b5e02db66c7da6cbf25ea9d
# Successfully built torch-sparse
# Installing collected packages: torch-sparse
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Successfully installed torch-sparse-0.6.8
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Looking in links: https://pytorch-geometric.com/whl/torch-1.10.0.html
# Collecting torch-cluster==1.5.8
#   Downloading torch_cluster-1.5.8.tar.gz (38 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: torch-cluster
#   Building wheel for torch-cluster (setup.py) ... done
#   Created wheel for torch-cluster: filename=torch_cluster-1.5.8-cp39-cp39-macosx_10_13_x86_64.whl size=344217 sha256=55d3f2ae6b61be196575d7efd1d4d5fc7f396fa555b97026510edbee0a725f3d
#   Stored in directory: /Users/maurizio/Library/Caches/pip/wheels/fb/76/c5/f99d1ca65720d192c534c49dd63b97ab370b26a3ff786130e3
# Successfully built torch-cluster
# Installing collected packages: torch-cluster
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Successfully installed torch-cluster-1.5.8
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Looking in links: https://pytorch-geometric.com/whl/torch-1.10.0.html
# Collecting torch-spline-conv==1.2.0
#   Downloading torch_spline_conv-1.2.0.tar.gz (12 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: torch-spline-conv
#   Building wheel for torch-spline-conv (setup.py) ... done
#   Created wheel for torch-spline-conv: filename=torch_spline_conv-1.2.0-cp39-cp39-macosx_10_13_x86_64.whl size=116188 sha256=f7d0c2c4f0cb38bc890e713f98cea879f1b3d3ce0bc0c43b5cae74bb279bd7f3
#   Stored in directory: /Users/maurizio/Library/Caches/pip/wheels/b4/fb/fc/e5ce379a35a328f7747e3f7ce72a159155ab6aa299668e9c5d
# Successfully built torch-spline-conv
# Installing collected packages: torch-spline-conv
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Successfully installed torch-spline-conv-1.2.0
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Collecting torch-geometric==1.6.3
#   Downloading torch_geometric-1.6.3.tar.gz (186 kB)
#      |████████████████████████████████| 186 kB 10.3 MB/s
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.9/site-packages (from torch-geometric==1.6.3) (1.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/site-packages (from torch-geometric==1.6.3) (1.19.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/site-packages (from torch-geometric==1.6.3) (4.62.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/site-packages (from torch-geometric==1.6.3) (1.7.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/site-packages (from torch-geometric==1.6.3) (2.6.3)
# Collecting python-louvain
#   Downloading python-louvain-0.15.tar.gz (204 kB)
#      |████████████████████████████████| 204 kB 65.2 MB/s
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/site-packages (from torch-geometric==1.6.3) (1.0.1)
# Collecting numba
#   Downloading numba-0.54.1.tar.gz (2.2 MB)
#      |████████████████████████████████| 2.2 MB 61.9 MB/s
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.9/site-packages (from torch-geometric==1.6.3) (2.26.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/site-packages (from torch-geometric==1.6.3) (1.3.4)
# Collecting rdflib
#   Downloading rdflib-6.0.2-py3-none-any.whl (407 kB)
#      |████████████████████████████████| 407 kB 67.0 MB/s
# Requirement already satisfied: h5py in /usr/local/lib/python3.9/site-packages (from torch-geometric==1.6.3) (3.1.0)
# Collecting googledrivedownloader
#   Downloading googledrivedownloader-0.4-py2.py3-none-any.whl (3.9 kB)
# Collecting ase
#   Downloading ase-3.22.0-py3-none-any.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 72.4 MB/s
# Collecting jinja2
#   Downloading Jinja2-3.0.3-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 34.6 MB/s
# Requirement already satisfied: matplotlib>=3.1.0 in /usr/local/lib/python3.9/site-packages (from ase->torch-geometric==1.6.3) (3.5.0)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.0.1-cp39-cp39-macosx_10_9_x86_64.whl (13 kB)
# Collecting llvmlite<0.38,>=0.37.0rc1
#   Downloading llvmlite-0.37.0-cp39-cp39-macosx_10_9_x86_64.whl (19.1 MB)
#      |████████████████████████████████| 19.1 MB 75.6 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/site-packages (from numba->torch-geometric==1.6.3) (59.1.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.9/site-packages (from pandas->torch-geometric==1.6.3) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.9/site-packages (from pandas->torch-geometric==1.6.3) (2.8.2)
# Collecting isodate
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 14.7 MB/s
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.9/site-packages (from rdflib->torch-geometric==1.6.3) (3.0.6)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/site-packages (from requests->torch-geometric==1.6.3) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/site-packages (from requests->torch-geometric==1.6.3) (2.0.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/site-packages (from requests->torch-geometric==1.6.3) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/site-packages (from requests->torch-geometric==1.6.3) (2021.10.8)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.9/site-packages (from scikit-learn->torch-geometric==1.6.3) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/site-packages (from scikit-learn->torch-geometric==1.6.3) (3.0.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/site-packages (from torch->torch-geometric==1.6.3) (3.7.4.3)
# Requirement already satisfied: setuptools-scm>=4 in /usr/local/lib/python3.9/site-packages (from matplotlib>=3.1.0->ase->torch-geometric==1.6.3) (6.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/site-packages (from matplotlib>=3.1.0->ase->torch-geometric==1.6.3) (4.28.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/site-packages (from matplotlib>=3.1.0->ase->torch-geometric==1.6.3) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/site-packages (from matplotlib>=3.1.0->ase->torch-geometric==1.6.3) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/site-packages (from matplotlib>=3.1.0->ase->torch-geometric==1.6.3) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/site-packages (from matplotlib>=3.1.0->ase->torch-geometric==1.6.3) (1.3.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas->torch-geometric==1.6.3) (1.15.0)
# Requirement already satisfied: tomli>=1.0.0 in /usr/local/lib/python3.9/site-packages (from setuptools-scm>=4->matplotlib>=3.1.0->ase->torch-geometric==1.6.3) (1.2.2)
# Building wheels for collected packages: torch-geometric, numba, python-louvain
#   Building wheel for torch-geometric (setup.py) ... done
#   Created wheel for torch-geometric: filename=torch_geometric-1.6.3-py3-none-any.whl size=322733 sha256=e66e3d5e9b7e7611454950713d65ace111b4c6ddda5856eaf9a110cce60e7d6d
#   Stored in directory: /Users/maurizio/Library/Caches/pip/wheels/9b/40/04/870b75c1d71cdc2e8374f26cf13640226645739d939b4fe957
#   Building wheel for numba (setup.py) ... done
#   Created wheel for numba: filename=numba-0.54.1-cp39-cp39-macosx_10_13_x86_64.whl size=2249024 sha256=c344ec6cf30eaa42adb284ccabbbac1d92c62e827c97f269a7a4fd7235666749
#   Stored in directory: /Users/maurizio/Library/Caches/pip/wheels/58/65/cc/788d1c14d665f12a617da8f3f6e162090695b6e9cd67b8b1e0
#   Building wheel for python-louvain (setup.py) ... done
#   Created wheel for python-louvain: filename=python_louvain-0.15-py3-none-any.whl size=9413 sha256=5edccb4965df13d4900d5d934fc47cc42496415b3597a226eec24e925882dd05
#   Stored in directory: /Users/maurizio/Library/Caches/pip/wheels/5a/f5/b9/2b37cd2ef0d5a3388179f2b48a6d4f2e8419abbf4213566ec1
# Successfully built torch-geometric numba python-louvain
# Installing collected packages: MarkupSafe, llvmlite, isodate, rdflib, python-louvain, numba, jinja2, googledrivedownloader, ase, torch-geometric
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Successfully installed MarkupSafe-2.0.1 ase-3.22.0 googledrivedownloader-0.4 isodate-0.6.0 jinja2-3.0.3 llvmlite-0.37.0 numba-0.54.1 python-louvain-0.15 rdflib-6.0.2 torch-geometric-1.6.3

# %% [markdown]
# # Load the dataset

# %%
dataname = 'KIDNEY'
import sys, os
sys.path.append(os.path.abspath('.'))
from wrappers.pygeo_wrapper import MyTUDataset
import shutil
shutil.unpack_archive(f'datasets/{dataname}.zip', '/Users/maurizio/Downloads')
dataset = MyTUDataset(dataname, path=f'/Users/maurizio/Downloads/{dataname}', use_node_attr=True, use_edge_attr=True)
print(dataset)
# Out:
# KIDNEY(299)

# %% [markdown]
# # Create model

# %%
import torch
from torch.nn import Linear
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from torch_geometric.nn import global_mean_pool


class GCN(torch.nn.Module):
    def __init__(self, hidden_channels):
        super(GCN, self).__init__()
        torch.manual_seed(12345)
        self.conv1 = GCNConv(dataset.num_node_features, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, hidden_channels)
        self.conv3 = GCNConv(hidden_channels, hidden_channels)
        self.lin = Linear(hidden_channels, dataset.num_classes)

    def forward(self, x, edge_index, batch):
        # 1. Obtain node embeddings 
        x = self.conv1(x, edge_index)
        x = x.relu()
        x = self.conv2(x, edge_index)
        x = x.relu()
        x = self.conv3(x, edge_index)

        # 2. Readout layer
        x = global_mean_pool(x, batch)  # [batch_size, hidden_channels]

        # 3. Apply a final classifier
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.lin(x)
        
        return x

model = GCN(hidden_channels=64)
print(model)
# Out:
# GCN(
#   (conv1): GCNConv(2887, 64)
#   (conv2): GCNConv(64, 64)
#   (conv3): GCNConv(64, 64)
#   (lin): Linear(in_features=64, out_features=3, bias=True)
# )

# %% [markdown]
# # Evaluate the model

# %%
from sklearn.model_selection import train_test_split
from torch_geometric.loader import DataLoader
import numpy as np
batch_size = 1
dataset = dataset.shuffle()
train_dataset, test_dataset = train_test_split(dataset, test_size=0.10, random_state=42)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

model = GCN(hidden_channels=64)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
criterion = torch.nn.CrossEntropyLoss()

def train():
    model.train()

    for data in train_loader:  # Iterate in batches over the training dataset.
         out = model(data.x, data.edge_index, data.batch)  # Perform a single forward pass.
         loss = criterion(out, data.y)  # Compute the loss.
         loss.backward()  # Derive gradients.
         optimizer.step()  # Update parameters based on gradients.
         optimizer.zero_grad()  # Clear gradients.

def test(loader):
     model.eval()

     correct = 0
     for data in loader:  # Iterate in batches over the training/test dataset.
         out = model(data.x, data.edge_index, data.batch)  
         pred = out.argmax(dim=1)  # Use the class with highest probability.
         correct += int((pred == data.y).sum())  # Check against ground-truth labels.
     return correct / len(loader.dataset)  # Derive ratio of correct predictions.

results = []
for epoch in range(1, 100):
    train()
    train_acc = test(train_loader)
    test_acc = test(test_loader)
    results.append(test_acc)
    print(f'Epoch: {epoch:03d}, Train Acc: {train_acc:.4f}, Test Acc: {test_acc:.4f}')
print("Done. Test acc: {}".format(np.mean(results)))
# Out:
# Epoch: 001, Train Acc: 0.5353, Test Acc: 0.5000
# Epoch: 002, Train Acc: 0.5353, Test Acc: 0.5000
# Epoch: 003, Train Acc: 0.6357, Test Acc: 0.5000
# Epoch: 004, Train Acc: 0.8699, Test Acc: 0.7333
# Epoch: 005, Train Acc: 0.9033, Test Acc: 0.7000
# Epoch: 006, Train Acc: 0.9926, Test Acc: 0.7667
# Epoch: 007, Train Acc: 1.0000, Test Acc: 0.6667
# Epoch: 008, Train Acc: 1.0000, Test Acc: 0.7667
# Epoch: 009, Train Acc: 1.0000, Test Acc: 0.7333
# Epoch: 010, Train Acc: 1.0000, Test Acc: 0.7333
# Epoch: 011, Train Acc: 1.0000, Test Acc: 0.7667
# Epoch: 012, Train Acc: 1.0000, Test Acc: 0.7667
# Epoch: 013, Train Acc: 1.0000, Test Acc: 0.7667
# Epoch: 014, Train Acc: 1.0000, Test Acc: 0.7333
# Epoch: 015, Train Acc: 1.0000, Test Acc: 0.7333
# Epoch: 016, Train Acc: 1.0000, Test Acc: 0.7000
# Epoch: 017, Train Acc: 1.0000, Test Acc: 0.7000
# Epoch: 018, Train Acc: 1.0000, Test Acc: 0.7000
# Epoch: 019, Train Acc: 1.0000, Test Acc: 0.7333
# Epoch: 020, Train Acc: 1.0000, Test Acc: 0.7000
# Epoch: 021, Train Acc: 1.0000, Test Acc: 0.7333
# Epoch: 022, Train Acc: 1.0000, Test Acc: 0.7333
# Epoch: 023, Train Acc: 1.0000, Test Acc: 0.7333
# Epoch: 024, Train Acc: 1.0000, Test Acc: 0.7333
# Epoch: 025, Train Acc: 1.0000, Test Acc: 0.7000
# Epoch: 026, Train Acc: 1.0000, Test Acc: 0.7000
# Epoch: 027, Train Acc: 1.0000, Test Acc: 0.7000
# Epoch: 028, Train Acc: 1.0000, Test Acc: 0.7000
# Epoch: 029, Train Acc: 1.0000, Test Acc: 0.7000
# Epoch: 030, Train Acc: 1.0000, Test Acc: 0.7000
# Epoch: 031, Train Acc: 1.0000, Test Acc: 0.7333
# Epoch: 032, Train Acc: 1.0000, Test Acc: 0.7000
# Epoch: 033, Train Acc: 1.0000, Test Acc: 0.7000
# Epoch: 034, Train Acc: 1.0000, Test Acc: 0.7333
# Epoch: 035, Train Acc: 1.0000, Test Acc: 0.7000
# Epoch: 036, Train Acc: 1.0000, Test Acc: 0.7000
# Epoch: 037, Train Acc: 1.0000, Test Acc: 0.7333
# Epoch: 038, Train Acc: 1.0000, Test Acc: 0.7333
# Epoch: 039, Train Acc: 1.0000, Test Acc: 0.7333
# Epoch: 040, Train Acc: 1.0000, Test Acc: 0.7333
# Epoch: 041, Train Acc: 1.0000, Test Acc: 0.7333
# Epoch: 042, Train Acc: 1.0000, Test Acc: 0.8000
# Epoch: 043, Train Acc: 0.8625, Test Acc: 0.6000
# Epoch: 044, Train Acc: 0.7249, Test Acc: 0.5333
# Epoch: 045, Train Acc: 1.0000, Test Acc: 0.8333
# Epoch: 046, Train Acc: 0.9963, Test Acc: 0.7333
# Epoch: 047, Train Acc: 1.0000, Test Acc: 0.7000
# Epoch: 048, Train Acc: 1.0000, Test Acc: 0.7000
# Epoch: 049, Train Acc: 1.0000, Test Acc: 0.7000
# Epoch: 050, Train Acc: 1.0000, Test Acc: 0.7000
# Epoch: 051, Train Acc: 1.0000, Test Acc: 0.7667
# Epoch: 052, Train Acc: 0.9554, Test Acc: 0.6333
# Epoch: 053, Train Acc: 1.0000, Test Acc: 0.7333
# Epoch: 054, Train Acc: 1.0000, Test Acc: 0.7333
# Epoch: 055, Train Acc: 1.0000, Test Acc: 0.7000
# Epoch: 056, Train Acc: 1.0000, Test Acc: 0.7333
# Epoch: 057, Train Acc: 1.0000, Test Acc: 0.7333
# Epoch: 058, Train Acc: 1.0000, Test Acc: 0.7333
# Epoch: 059, Train Acc: 1.0000, Test Acc: 0.7333
# Epoch: 060, Train Acc: 1.0000, Test Acc: 0.7667
# Epoch: 061, Train Acc: 1.0000, Test Acc: 0.7667
# Epoch: 062, Train Acc: 1.0000, Test Acc: 0.7667
# Epoch: 063, Train Acc: 1.0000, Test Acc: 0.7667
# Epoch: 064, Train Acc: 1.0000, Test Acc: 0.7667
